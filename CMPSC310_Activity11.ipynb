# %% [markdown]
# <a href="https://colab.research.google.com/github/CMPSC-310-AI-Spring2023/activity09_image-manipulation-MilesF25/blob/main/CMPSC310_Activity11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Activity 11: Distributions and Bayes Algorithm **

# %% [markdown]
# ## Binomial Distribution
#
# the probability seems to be around 50
#
# The p variable needs to be a float

# %%
import numpy as np

n=100 # number of trials
p=0.5 # probability of success
s=100 # size
binomial = np.random.binomial(n,p,s)
print(binomial)

import matplotlib.pyplot as plt

plt.axis([0, 100, 0, 100])
plt.plot(binomial,linewidth=2, color='r')
plt.show()
# Out:
# [55 53 48 53 48 47 41 46 53 61 54 45 59 60 49 56 37 55 59 43 53 55 56 54
#  49 48 54 52 50 50 45 47 55 49 44 48 50 53 53 45 50 49 53 54 48 49 51 60
#  52 45 38 49 54 57 50 39 49 47 57 58 47 44 55 52 49 61 42 43 52 49 51 44
#  52 52 62 59 50 48 50 46 50 40 52 55 50 44 43 45 42 50 44 54 42 51 50 53
#  45 51 51 42]

# %% [markdown]
# ## Uniform Distribution
# size is the amount of data
#
# the data goes up and down a lot

# %%
import numpy as np

uniform = np.random.uniform(low=1, high=10,size=100)
print(uniform)

import matplotlib.pyplot as plt

plt.axis([0, 100, 0, 10])
plt.plot(uniform,linewidth=2, color='y')
plt.show()
# Out:
# [8.38375503 2.95031749 7.42816293 2.13252278 1.36803439 9.62878607
#  9.18801045 4.84291773 6.55232404 7.75295341 9.83298973 5.48652254
#  1.0963019  6.64084652 5.67089085 9.80684747 8.17691663 3.98716343
#  2.46386218 7.3842408  4.85736959 9.90879682 8.98698991 1.06792118
#  6.65034627 9.58085829 3.48325367 2.16701564 4.41032156 3.64457472
#  5.89771125 2.78092037 3.59132294 9.01860815 6.15793557 3.02435173
#  8.77533067 8.26297373 1.13234295 1.27673672 7.9971055  6.21236913
#  1.41941351 6.12062354 5.17556826 1.6572181  5.39003275 3.10829325
#  3.80565092 6.50630121 2.11905701 7.38589304 4.89679331 2.29450119
#  2.62575389 5.99356959 5.9875603  5.47384649 5.08418955 8.49988564
#  3.79311253 2.46338034 6.1219416  1.38255654 4.49235449 8.29024466
#  2.76027835 6.13236047 1.34711809 7.51931348 6.06063391 2.16882205
#  8.73567979 8.96138652 9.01813454 4.8907516  3.27965376 7.01829256
#  2.39897254 6.51830243 1.3958738  4.28138486 9.438719   6.69839955
#  8.65505821 9.30596373 1.05589141 6.4918958  3.15095996 6.3810478
#  4.57776457 2.39170621 3.49713192 9.88464634 3.63777016 3.84062217
#  7.2022911  8.022064   9.84728318 3.59352709]

# %% [markdown]
# ## Normal Distribution
#
# The data points are around 0.2

# %%
import numpy as np
mu, sigma = 0, 0.1 # mean and standard deviation
normal = np.random.normal(mu, sigma, 100)

import matplotlib.pyplot as plt

plt.axis([0, 100, 0, 1])
plt.plot(normal,linewidth=2, color='r')
plt.show()

# %% [markdown]
# ## Bayes Algorithm
#
# TODO: Add experimentation
#
# Ref: https://scikit-learn.org/stable/modules/naive_bayes.html

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB # Gaussian is normal distribution
X, y = load_iris(return_X_y=True) # https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)
print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 75 points : 4
